# %%
import pandas as pd

# %%
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import mlflow
from mlflow.models import infer_signature

# %%
#load the dataset

X,y= datasets.load_iris(return_X_y=True)

#split the data into traning and test sets 
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)
# define model hyperparameter
Parameters={"penalty":"l2","solver":"lbfgs","max_iter":1000,"multi_class":"auto","random_state":8888}
# define model
model=LogisticRegression(**Parameters)
# train the model
model.fit(X_train,y_train)
# Out:
# /Users/ahmedgaber/Desktop/mlOps/venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=1000, multi_class='auto', random_state=8888)

# %%
#predction on the dataset
y_pred=model.predict(X_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy",accuracy)
# Out:
# Accuracy 1.0

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("logistic-regression-iris")

# Define hyperparameters
# Start MLflow run
with mlflow.start_run():
    mlflow.log_params(Parameters)
    mlflow.log_metric("accuracy", accuracy)
    
    # Log model
    signature = infer_signature(X_train,model.predict(X_train))

    mlflow.sklearn.log_model(
        sk_model= model,
        artifact_path="iris_model",
        input_example=X_train,
        signature=signature,
       )
# Out:
# 🏃 View run redolent-loon-780 at: http://127.0.0.1:5000/#/experiments/655167709060330260/runs/65853cec63ae43b2b64e8fab5ea530da
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/655167709060330260

# %%
Parameters={"solver":"newton-cg","max_iter":1000,"multi_class":"auto","random_state":1000}
# define model
model=LogisticRegression(**Parameters)
# train the model
model.fit(X_train,y_train)

#predction on the dataset
y_pred=model.predict(X_test)

accuracy=accuracy_score(y_test,y_pred)
print("Accuracy",accuracy)

mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("logistic-regression-iris")

# Define hyperparameters
# Start MLflow run
with mlflow.start_run():
    mlflow.log_params(Parameters)
    mlflow.log_metric("accuracy", accuracy)
    
    # Log model
    signature = infer_signature(X_train,model.predict(X_train))

    mlflow.sklearn.log_model(
        sk_model= model,
        artifact_path="iris_model",
        input_example=X_train,
        signature=signature,
       )
# Out:
# /Users/ahmedgaber/Desktop/mlOps/venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Accuracy 1.0
# Registered model 'tracking quick start' already exists. Creating a new version of this model...
# 2025/05/18 12:49:34 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: tracking quick start, version 4
# 🏃 View run gentle-cub-716 at: http://127.0.0.1:5000/#/experiments/655167709060330260/runs/00c6ba5c070f4c069d053ae07ea4e812
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/655167709060330260
# Created version '4' of model 'tracking quick start'.

# %% [markdown]
# ## inferencing and validating the Model

# %%
import mlflow
from mlflow.models import Model

model_uri = 'runs:/745cadda84e94c86a9e67536852868e8/iris_model'
# The model is logged with an input example
pyfunc_model = mlflow.pyfunc.load_model(model_uri)
input_data = pyfunc_model.input_example

# Verify the model with the provided input data using the logged dependencies.
# For more details, refer to:
# https://mlflow.org/docs/latest/models.html#validate-models-before-deployment
mlflow.models.predict(
    model_uri=model_uri,
    input_data=input_data,
    env_manager="uv",
)
# Out:
# 2025/05/18 12:49:38 INFO mlflow.models.flavor_backend_registry: Selected backend for flavor 'python_function'
# 2025/05/18 12:49:38 INFO mlflow.utils.virtualenv: Creating a new environment in /var/folders/9l/8_594kh91jbghzdwy8g1ztpr0000gp/T/tmpc1cs3vnv/envs/virtualenv_envs/mlflow-fc21b5a3d6bca4b52d34d00a28b497205f6a0d60 with python version 3.13.1 using uv
# Using CPython 3.13.1 interpreter at: /usr/local/opt/python@3.13/bin/python3.13
# Creating virtual environment at: /var/folders/9l/8_594kh91jbghzdwy8g1ztpr0000gp/T/tmpc1cs3vnv/envs/virtualenv_envs/mlflow-fc21b5a3d6bca4b52d34d00a28b497205f6a0d60
# Activate with: source /var/folders/9l/8_594kh91jbghzdwy8g1ztpr0000gp/T/tmpc1cs3vnv/envs/virtualenv_envs/mlflow-fc21b5a3d6bca4b52d34d00a28b497205f6a0d60/bin/activate
# 2025/05/18 12:49:38 INFO mlflow.utils.virtualenv: Installing dependencies
# ...

# %% [markdown]
# ## Load the model back for prediction as a generic python function model

# %%
loaded_model = mlflow.pyfunc.load_model(model_uri)

predictions = loaded_model.predict(X_test)

# 1) Load feature names
iris_feature_names = datasets.load_iris().feature_names

# 2) Build your results DataFrame
results=pd.DataFrame(X_test,columns=iris_feature_names)

# 3) Add actual vs. predicted
results["acual_claa"]=y_test
results["predicted_class"]=predictions

# %%
# 4) Inspect
print(results)
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 6.3               2.8                5.1               1.5
# 1                 4.8               3.0                1.4               0.3
# 2                 7.9               3.8                6.4               2.0
# 3                 7.4               2.8                6.1               1.9
# 4                 5.7               4.4                1.5               0.4
# 5                 7.2               3.6                6.1               2.5
# 6                 5.9               3.0                4.2               1.5
# 7                 5.0               3.5                1.3               0.3
# 8                 6.7               3.1                4.4               1.4
# 9                 5.5               2.5                4.0               1.3
# 10                4.9               3.1                1.5               0.1
# ...

# %% [markdown]
# ## inferencing from the model from model registery

# %%
import mlflow.sklearn
model_name="tracking quick start"
model_version="latest"
model_uri=f"models:/{model_name}/{model_version}"
model=mlflow.sklearn.load_model(model_uri)
model
# Out:
# LogisticRegression(max_iter=1000, multi_class='auto', random_state=1000,
#                    solver='newton-cg')

# %%
model_uri
# Out:
# 'models:/tracking quick start/latest'

# %%
y_pred_new=model.predict(X_test)
y_pred_new
# Out:
# array([2, 0, 2, 2, 0, 2, 1, 0, 1, 1, 0, 0, 2, 2, 0, 1, 0, 2, 0, 0, 2, 0,
#        1, 2, 1, 0, 1, 0, 1, 0])
